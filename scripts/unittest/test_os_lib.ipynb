# %%
# Append base directory
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
libpath = os.path.join(parentdir, "lib")
sys.path.insert(0, libpath) 
print("Appended library directory", libpath)

# User libraries
from os_lib import getfiles_walk
from qt_wrapper import gui_fpath
# Out:
# Appended library directory /media/aleksejs/DataHDD/work/codes/comp-neuro/analysis-tracking/dlc-scripts/scripts/lib

# %%
# Choose folder to walk
root_path = gui_fpath("Select root directory to sweep", "./")

# %%
# Sweep
keys = [".mat"]
walkpaths = getfiles_walk(root_path, keys)

print(walkpaths)
# Out:
# [['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_18_b'
#   'lick_traces.mat']
#  ['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_18_b'
#   'mtp_1_2015_06_18_b.mat']
#  ['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_18_b'
#   'RT_264.mat']
#  ['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_18_b'
#   'RT_265.mat']
#  ['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_19_b'
#   'lick_traces.mat']
#  ['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_19_b'
#   'mtp_1_2015_06_19_b.mat']
#  ['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_19_b'
#   'RT_264.mat']
#  ['/mnt/hifo_scratch1/Yaro/data_for_TE/behavior/mtp_12_lick_reaction/mtp_1/mtp_1_2015_06_19_b'
#   'RT_265.mat']
# ...
